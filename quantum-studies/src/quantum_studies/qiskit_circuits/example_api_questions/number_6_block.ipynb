# %%
from qiskit import QuantumCircuit, execute
from qiskit.providers.aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
# %matplotlib inline

qc = QuantumCircuit(1, 1)
qc.ry(theta=math.pi / 2, qubit=0)  # Apply a rotation around the Y-axis by pi/2 radians - this is the same as a Hadamard gate qc.h(0)
simulator = Aer.get_backend('statevector_simulator')
job = execute(qc, simulator)
result = job.result()
outputstate = result.get_statevector()
plot_bloch_multivector(outputstate)
# Out:
# /home/vscode/.cache/pypoetry/virtualenvs/quantum-studies-bgrKsKb0-py3.8/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
