# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import DensityMatrix

def create_bell_circuit():
    qc = QuantumCircuit(2)
    qc.h(0)
    qc.cx(0, 1)
    return qc

qc_bell = create_bell_circuit()
psi_plus = DensityMatrix(qc_bell)

print("Density Matrix (No Noise):")
psi_plus.draw('latex')
# Out:
# Density Matrix (No Noise):
# $$
#
# \begin{bmatrix}
# \frac{1}{2} & 0 & 0 & \frac{1}{2}  \\
#  0 & 0 & 0 & 0  \\
#  0 & 0 & 0 & 0  \\
#  \frac{1}{2} & 0 & 0 & \frac{1}{2}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# $|\Phi^+\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$

# %%
from qiskit.visualization import plot_state_city

print("Bell State |φ+> Density Matrix from Circuit:")
print(psi_plus.data)

psi_plus_statevector = psi_plus.to_statevector()
plot_state_city(psi_plus, title="Bell State |φ+>", color=["blue", "green"])
# Out:
# Bell State |φ+> Density Matrix from Circuit:
# [[0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]]

# %%
from qiskit.visualization import plot_state_paulivec
psi_minus_circuit = QuantumCircuit(2)
psi_minus_circuit.h(0)
psi_minus_circuit.cx(0, 1)
psi_minus_circuit.z(1)  # Apply Z gate to the second qubit
psi_minus = DensityMatrix(psi_minus_circuit)
print("Density Matrix (No Noise) for |ψ−>):")
psi_minus.draw('latex')

print("Bell State |ψ−> Density Matrix from Circuit:")
print(psi_minus.data)
psi_minus_statevector = psi_minus.to_statevector()
plot_state_city(psi_minus_statevector, title="Bell State |ψ−>", color=["red", "orange"])
plot_state_paulivec(psi_minus_statevector, title="Bell State |ψ−> Pauli Vector", color=["red", "orange"])
# Out:
# Density Matrix (No Noise) for |ψ−>):
# Bell State |ψ−> Density Matrix from Circuit:
# [[ 0.5+0.j  0. +0.j  0. +0.j -0.5+0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [-0.5+0.j  0. +0.j  0. +0.j  0.5+0.j]]
